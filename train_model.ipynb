# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten, BatchNormalization
from keras import Model
from keras.regularizers import l2
from keras.optimizers import Adam, adamw_experimental
from keras.preprocessing.image import ImageDataGenerator
from keras import regularizers
from keras.callbacks import ModelCheckpoint
import os

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Generators

# %%
imageGeneration = ImageDataGenerator(
    rescale=1./255,
    
    # Applies image augmentation to reduce overfitting
    rotation_range=30,
    fill_mode='nearest',
    width_shift_range=0.15,
    height_shift_range=0.15,
    horizontal_flip=True,
    shear_range=0.01,
    zoom_range=-0.01,
    brightness_range=[0.5, 1.5],
    )

# %%
trainGenerator = imageGeneration.flow_from_directory(
    'images/train',
    target_size=(48, 48),
    batch_size=32,
    color_mode='grayscale',
    class_mode='categorical',
    shuffle=True,
)
validationGenerator = imageGeneration.flow_from_directory(
    'images/validation',
    target_size=(48, 48),
    batch_size=32,
    color_mode='grayscale',
    class_mode='categorical',
    shuffle=True
)
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.

# %% [markdown]
# ## Image Analysis

# %% [markdown]
# ### Meant to show how the image augmentation affected the images

# %%
images, labels = next(trainGenerator)
fig, axs = plt.subplots(8, 4, figsize=(10, 10))

for i in range(32):
    ax = axs[i//4, i%4]
    ax.imshow(images[i, :, :, 0], cmap='gray')
    ax.axis('off')

plt.show()

# %%
trainDir = 'images/train/'
labels = [label.name for label in os.scandir(trainDir) if label.is_dir()]
expressionsCount = {}

# %%
for label in labels:
    labelPath = os.path.join(trainDir, label)
    imgCount = len([image for image in os.listdir(labelPath) if
                    os.path.isfile(os.path.join(labelPath, image))])
    
    expressionsCount[label] = imgCount

# %%
expressionsCountsDf = pd.DataFrame.from_dict(expressionsCount, orient = 'index', columns = ['count'])
sns.barplot(x = expressionsCountsDf.index, y = expressionsCountsDf['count'])
plt.xlabel('Expression')
plt.ylabel('Count')
plt.show()

# %%
trainGenerator.image_shape
# Out:
# (48, 48, 1)

# %%
validationGenerator.image_shape
# Out:
# (48, 48, 1)

# %% [markdown]
# ## Model Building

# %%
emotionModel = Sequential()

# Layer 1
emotionModel.add(Conv2D(32, kernel_size=(3, 3), padding="same", activation='relu', input_shape=(48, 48, 1)))
emotionModel.add(Conv2D(32, kernel_size=(3, 3), padding="same", activation='relu'))
emotionModel.add(Conv2D(32, kernel_size=(1, 1), activation='relu'))
emotionModel.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

## Applies Batch Normalisation for regulisation, further preventing overfitting   
emotionModel.add(BatchNormalization())
 
# Layer 2
emotionModel.add(Conv2D(64, kernel_size=(3, 3), padding="same", activation='relu'))
emotionModel.add(Conv2D(64, kernel_size=(3, 3), padding="same", activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
emotionModel.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
emotionModel.add(BatchNormalization())
 
# Layer 3
emotionModel.add(Conv2D(128, kernel_size=(3, 3), padding="same", activation='relu'))
emotionModel.add(Conv2D(128, kernel_size=(3, 3), padding="same", activation='relu'))
emotionModel.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
emotionModel.add(BatchNormalization())

# layer 4
emotionModel.add(Conv2D(256, kernel_size=(3, 3), padding="same", activation='relu'))
emotionModel.add(Conv2D(256, kernel_size=(3, 3), padding="same", activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
emotionModel.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
emotionModel.add(BatchNormalization())

# Layer 5 - Final
emotionModel.add(Flatten())
emotionModel.add(Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
emotionModel.add(Dropout(0.1))
emotionModel.add(Dense(7, activation='softmax'))

emotionModel.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0001, decay=1e-6), metrics=['accuracy'])

# %% [markdown]
# ## Model Info

# %%
emotionModel.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_33 (Conv2D)          (None, 48, 48, 32)        320
#
#  conv2d_34 (Conv2D)          (None, 48, 48, 32)        9248
#
#  conv2d_35 (Conv2D)          (None, 48, 48, 32)        1056
#
#  max_pooling2d_13 (MaxPoolin  (None, 24, 24, 32)       0
#  g2D)
#
#  batch_normalization_13 (Bat  (None, 24, 24, 32)       128
#  chNormalization)
#
#  conv2d_36 (Conv2D)          (None, 24, 24, 64)        18496
#
#  conv2d_37 (Conv2D)          (None, 24, 24, 64)        36928
#
#  max_pooling2d_14 (MaxPoolin  (None, 12, 12, 64)       0
#  g2D)
#
#  batch_normalization_14 (Bat  (None, 12, 12, 64)       256
#  chNormalization)
#
#  conv2d_38 (Conv2D)          (None, 12, 12, 128)       73856
#
#  conv2d_39 (Conv2D)          (None, 12, 12, 128)       147584
#
#  max_pooling2d_15 (MaxPoolin  (None, 6, 6, 128)        0
#  g2D)
#
#  batch_normalization_15 (Bat  (None, 6, 6, 128)        512
#  chNormalization)
#
#  conv2d_40 (Conv2D)          (None, 6, 6, 256)         295168
#
#  conv2d_41 (Conv2D)          (None, 6, 6, 256)         590080
#
#  max_pooling2d_16 (MaxPoolin  (None, 3, 3, 256)        0
#  g2D)
#
#  batch_normalization_16 (Bat  (None, 3, 3, 256)        1024
#  chNormalization)
#
#  flatten_3 (Flatten)         (None, 2304)              0
#
#  dense_6 (Dense)             (None, 256)               590080
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 1,766,535
# Trainable params: 1,765,575
# Non-trainable params: 960
# _________________________________________________________________

# %% [markdown]
# ## Model Saving

# %%
try:
    os.mkdir('checkpoint')
except:
    pass

# %%
fileName = 'savedModel.h5'
checkpointDir = os.path.join('checkpoint', fileName)
callback = ModelCheckpoint(filepath = checkpointDir, monitor = 'val_accuracy', verbose = 1, save_best_only = True, mode = 'max')

# %% [markdown]
# ## Model Run

# %%
# May take a couple hours

emotionalModelInfo = emotionModel.fit(
    trainGenerator,
    steps_per_epoch = len(trainGenerator),
    epochs = 50,
    validation_data = validationGenerator,  
    validation_steps= len(validationGenerator),
    callbacks=[callback]
)
# Out:
# Epoch 1/50
# 901/901 [==============================] - ETA: 0s - loss: 8.2937 - accuracy: 0.2412
# Epoch 1: val_accuracy improved from -inf to 0.27073, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 170s 187ms/step - loss: 8.2937 - accuracy: 0.2412 - val_loss: 6.7084 - val_accuracy: 0.2707
# Epoch 2/50
# 901/901 [==============================] - ETA: 0s - loss: 5.3968 - accuracy: 0.2863
# Epoch 2: val_accuracy improved from 0.27073 to 0.31857, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 169s 188ms/step - loss: 5.3968 - accuracy: 0.2863 - val_loss: 4.2621 - val_accuracy: 0.3186
# Epoch 3/50
# 901/901 [==============================] - ETA: 0s - loss: 3.5042 - accuracy: 0.3409
# Epoch 3: val_accuracy improved from 0.31857 to 0.36046, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 156s 173ms/step - loss: 3.5042 - accuracy: 0.3409 - val_loss: 2.9222 - val_accuracy: 0.3605
# Epoch 4/50
# 901/901 [==============================] - ETA: 0s - loss: 2.5200 - accuracy: 0.4048
# Epoch 4: val_accuracy improved from 0.36046 to 0.43957, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 159s 176ms/step - loss: 2.5200 - accuracy: 0.4048 - val_loss: 2.2093 - val_accuracy: 0.4396
# Epoch 5/50
# 901/901 [==============================] - ETA: 0s - loss: 2.0232 - accuracy: 0.4650
# Epoch 5: val_accuracy improved from 0.43957 to 0.48089, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 161s 179ms/step - loss: 2.0232 - accuracy: 0.4650 - val_loss: 1.8794 - val_accuracy: 0.4809
# Epoch 6/50
# 901/901 [==============================] - ETA: 0s - loss: 1.7739 - accuracy: 0.4942
# Epoch 6: val_accuracy improved from 0.48089 to 0.48726, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 151s 167ms/step - loss: 1.7739 - accuracy: 0.4942 - val_loss: 1.7342 - val_accuracy: 0.4873
# Epoch 7/50
# 901/901 [==============================] - ETA: 0s - loss: 1.6167 - accuracy: 0.5139
# Epoch 7: val_accuracy improved from 0.48726 to 0.51967, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 160s 178ms/step - loss: 1.6167 - accuracy: 0.5139 - val_loss: 1.5680 - val_accuracy: 0.5197
# Epoch 8/50
# 901/901 [==============================] - ETA: 0s - loss: 1.5160 - accuracy: 0.5303
# Epoch 8: val_accuracy improved from 0.51967 to 0.52378, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 164s 182ms/step - loss: 1.5160 - accuracy: 0.5303 - val_loss: 1.5251 - val_accuracy: 0.5238
# Epoch 9/50
# 901/901 [==============================] - ETA: 0s - loss: 1.4531 - accuracy: 0.5452
# Epoch 9: val_accuracy did not improve from 0.52378
# 901/901 [==============================] - 158s 176ms/step - loss: 1.4531 - accuracy: 0.5452 - val_loss: 1.4845 - val_accuracy: 0.5226
# Epoch 10/50
# 901/901 [==============================] - ETA: 0s - loss: 1.3983 - accuracy: 0.5527
# Epoch 10: val_accuracy improved from 0.52378 to 0.54939, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 158s 175ms/step - loss: 1.3983 - accuracy: 0.5527 - val_loss: 1.3949 - val_accuracy: 0.5494
# Epoch 11/50
# 901/901 [==============================] - ETA: 0s - loss: 1.3592 - accuracy: 0.5626
# Epoch 11: val_accuracy improved from 0.54939 to 0.55052, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 158s 176ms/step - loss: 1.3592 - accuracy: 0.5626 - val_loss: 1.3797 - val_accuracy: 0.5505
# Epoch 12/50
# 901/901 [==============================] - ETA: 0s - loss: 1.3251 - accuracy: 0.5704
# Epoch 12: val_accuracy improved from 0.55052 to 0.56369, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 158s 176ms/step - loss: 1.3251 - accuracy: 0.5704 - val_loss: 1.3409 - val_accuracy: 0.5637
# Epoch 13/50
# 901/901 [==============================] - ETA: 0s - loss: 1.3043 - accuracy: 0.5760
# Epoch 13: val_accuracy did not improve from 0.56369
# 901/901 [==============================] - 159s 176ms/step - loss: 1.3043 - accuracy: 0.5760 - val_loss: 1.3279 - val_accuracy: 0.5627
# Epoch 14/50
# 901/901 [==============================] - ETA: 0s - loss: 1.2784 - accuracy: 0.5839
# Epoch 14: val_accuracy improved from 0.56369 to 0.57345, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 159s 177ms/step - loss: 1.2784 - accuracy: 0.5839 - val_loss: 1.3105 - val_accuracy: 0.5735
# Epoch 15/50
# 901/901 [==============================] - ETA: 0s - loss: 1.2635 - accuracy: 0.5870
# Epoch 15: val_accuracy improved from 0.57345 to 0.57628, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 160s 178ms/step - loss: 1.2635 - accuracy: 0.5870 - val_loss: 1.3037 - val_accuracy: 0.5763
# Epoch 16/50
# 901/901 [==============================] - ETA: 0s - loss: 1.2539 - accuracy: 0.5913
# Epoch 16: val_accuracy improved from 0.57628 to 0.58038, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 160s 178ms/step - loss: 1.2539 - accuracy: 0.5913 - val_loss: 1.2738 - val_accuracy: 0.5804
# Epoch 17/50
# 901/901 [==============================] - ETA: 0s - loss: 1.2311 - accuracy: 0.5979
# Epoch 17: val_accuracy did not improve from 0.58038
# 901/901 [==============================] - 170s 189ms/step - loss: 1.2311 - accuracy: 0.5979 - val_loss: 1.2743 - val_accuracy: 0.5797
# Epoch 18/50
# 901/901 [==============================] - ETA: 0s - loss: 1.2204 - accuracy: 0.6014
# Epoch 18: val_accuracy did not improve from 0.58038
# 901/901 [==============================] - 174s 193ms/step - loss: 1.2204 - accuracy: 0.6014 - val_loss: 1.3192 - val_accuracy: 0.5723
# Epoch 19/50
# 901/901 [==============================] - ETA: 0s - loss: 1.2103 - accuracy: 0.6037
# Epoch 19: val_accuracy improved from 0.58038 to 0.58491, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 177s 196ms/step - loss: 1.2103 - accuracy: 0.6037 - val_loss: 1.2648 - val_accuracy: 0.5849
# Epoch 20/50
# 901/901 [==============================] - ETA: 0s - loss: 1.1988 - accuracy: 0.6069
# Epoch 20: val_accuracy improved from 0.58491 to 0.59057, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 165s 183ms/step - loss: 1.1988 - accuracy: 0.6069 - val_loss: 1.2488 - val_accuracy: 0.5906
# Epoch 21/50
# 901/901 [==============================] - ETA: 0s - loss: 1.1832 - accuracy: 0.6138
# Epoch 21: val_accuracy improved from 0.59057 to 0.59510, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 174s 193ms/step - loss: 1.1832 - accuracy: 0.6138 - val_loss: 1.2335 - val_accuracy: 0.5951
# Epoch 22/50
# 901/901 [==============================] - ETA: 0s - loss: 1.1740 - accuracy: 0.6152
# Epoch 22: val_accuracy improved from 0.59510 to 0.60076, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 176s 195ms/step - loss: 1.1740 - accuracy: 0.6152 - val_loss: 1.2344 - val_accuracy: 0.6008
# Epoch 23/50
# 901/901 [==============================] - ETA: 0s - loss: 1.1672 - accuracy: 0.6189
# Epoch 23: val_accuracy did not improve from 0.60076
# 901/901 [==============================] - 178s 197ms/step - loss: 1.1672 - accuracy: 0.6189 - val_loss: 1.2464 - val_accuracy: 0.5954
# Epoch 24/50
# 901/901 [==============================] - ETA: 0s - loss: 1.1576 - accuracy: 0.6238
# Epoch 24: val_accuracy improved from 0.60076 to 0.60161, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 183s 203ms/step - loss: 1.1576 - accuracy: 0.6238 - val_loss: 1.2093 - val_accuracy: 0.6016
# Epoch 25/50
# 901/901 [==============================] - ETA: 0s - loss: 1.1477 - accuracy: 0.6232
# Epoch 25: val_accuracy did not improve from 0.60161
# 901/901 [==============================] - 184s 204ms/step - loss: 1.1477 - accuracy: 0.6232 - val_loss: 1.2004 - val_accuracy: 0.5971
# Epoch 26/50
# 901/901 [==============================] - ETA: 0s - loss: 1.1404 - accuracy: 0.6274
# Epoch 26: val_accuracy did not improve from 0.60161
# 901/901 [==============================] - 172s 191ms/step - loss: 1.1404 - accuracy: 0.6274 - val_loss: 1.2315 - val_accuracy: 0.5969
# Epoch 27/50
# 901/901 [==============================] - ETA: 0s - loss: 1.1274 - accuracy: 0.6311
# Epoch 27: val_accuracy did not improve from 0.60161
# 901/901 [==============================] - 171s 190ms/step - loss: 1.1274 - accuracy: 0.6311 - val_loss: 1.2193 - val_accuracy: 0.6009
# Epoch 28/50
# 901/901 [==============================] - ETA: 0s - loss: 1.1259 - accuracy: 0.6310
# Epoch 28: val_accuracy improved from 0.60161 to 0.61803, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 176s 195ms/step - loss: 1.1259 - accuracy: 0.6310 - val_loss: 1.1746 - val_accuracy: 0.6180
# Epoch 29/50
# 901/901 [==============================] - ETA: 0s - loss: 1.1115 - accuracy: 0.6352
# Epoch 29: val_accuracy did not improve from 0.61803
# 901/901 [==============================] - 182s 202ms/step - loss: 1.1115 - accuracy: 0.6352 - val_loss: 1.1665 - val_accuracy: 0.6176
# Epoch 30/50
# 901/901 [==============================] - ETA: 0s - loss: 1.1079 - accuracy: 0.6400
# Epoch 30: val_accuracy did not improve from 0.61803
# 901/901 [==============================] - 174s 193ms/step - loss: 1.1079 - accuracy: 0.6400 - val_loss: 1.1813 - val_accuracy: 0.6162
# Epoch 31/50
# 901/901 [==============================] - ETA: 0s - loss: 1.1049 - accuracy: 0.6390
# Epoch 31: val_accuracy improved from 0.61803 to 0.61916, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 180s 199ms/step - loss: 1.1049 - accuracy: 0.6390 - val_loss: 1.1745 - val_accuracy: 0.6192
# Epoch 32/50
# 901/901 [==============================] - ETA: 0s - loss: 1.0986 - accuracy: 0.6429
# Epoch 32: val_accuracy did not improve from 0.61916
# 901/901 [==============================] - 172s 190ms/step - loss: 1.0986 - accuracy: 0.6429 - val_loss: 1.1759 - val_accuracy: 0.6138
# Epoch 33/50
# 901/901 [==============================] - ETA: 0s - loss: 1.0917 - accuracy: 0.6411
# Epoch 33: val_accuracy did not improve from 0.61916
# 901/901 [==============================] - 176s 196ms/step - loss: 1.0917 - accuracy: 0.6411 - val_loss: 1.2115 - val_accuracy: 0.6081
# Epoch 34/50
# 901/901 [==============================] - ETA: 0s - loss: 1.0799 - accuracy: 0.6497
# Epoch 34: val_accuracy did not improve from 0.61916
# 901/901 [==============================] - 175s 194ms/step - loss: 1.0799 - accuracy: 0.6497 - val_loss: 1.2072 - val_accuracy: 0.6026
# Epoch 35/50
# 901/901 [==============================] - ETA: 0s - loss: 1.0787 - accuracy: 0.6513
# Epoch 35: val_accuracy did not improve from 0.61916
# 901/901 [==============================] - 172s 191ms/step - loss: 1.0787 - accuracy: 0.6513 - val_loss: 1.1655 - val_accuracy: 0.6134
# Epoch 36/50
# 901/901 [==============================] - ETA: 0s - loss: 1.0762 - accuracy: 0.6488
# Epoch 36: val_accuracy did not improve from 0.61916
# 901/901 [==============================] - 172s 190ms/step - loss: 1.0762 - accuracy: 0.6488 - val_loss: 1.2120 - val_accuracy: 0.6091
# Epoch 37/50
# 901/901 [==============================] - ETA: 0s - loss: 1.0697 - accuracy: 0.6515
# Epoch 37: val_accuracy improved from 0.61916 to 0.61973, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 168s 187ms/step - loss: 1.0697 - accuracy: 0.6515 - val_loss: 1.1657 - val_accuracy: 0.6197
# Epoch 38/50
# 901/901 [==============================] - ETA: 0s - loss: 1.0615 - accuracy: 0.6560
# Epoch 38: val_accuracy did not improve from 0.61973
# 901/901 [==============================] - 175s 195ms/step - loss: 1.0615 - accuracy: 0.6560 - val_loss: 1.1626 - val_accuracy: 0.6189
# Epoch 39/50
# 901/901 [==============================] - ETA: 0s - loss: 1.0623 - accuracy: 0.6546
# Epoch 39: val_accuracy improved from 0.61973 to 0.62242, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 180s 199ms/step - loss: 1.0623 - accuracy: 0.6546 - val_loss: 1.1668 - val_accuracy: 0.6224
# Epoch 40/50
# 901/901 [==============================] - ETA: 0s - loss: 1.0559 - accuracy: 0.6580
# Epoch 40: val_accuracy did not improve from 0.62242
# 901/901 [==============================] - 156s 174ms/step - loss: 1.0559 - accuracy: 0.6580 - val_loss: 1.1795 - val_accuracy: 0.6187
# Epoch 41/50
# 901/901 [==============================] - ETA: 0s - loss: 1.0490 - accuracy: 0.6582
# Epoch 41: val_accuracy improved from 0.62242 to 0.63388, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 165s 183ms/step - loss: 1.0490 - accuracy: 0.6582 - val_loss: 1.1351 - val_accuracy: 0.6339
# Epoch 42/50
# 901/901 [==============================] - ETA: 0s - loss: 1.0413 - accuracy: 0.6642
# Epoch 42: val_accuracy did not improve from 0.63388
# 901/901 [==============================] - 178s 198ms/step - loss: 1.0413 - accuracy: 0.6642 - val_loss: 1.1921 - val_accuracy: 0.6115
# Epoch 43/50
# 901/901 [==============================] - ETA: 0s - loss: 1.0375 - accuracy: 0.6662
# Epoch 43: val_accuracy improved from 0.63388 to 0.63530, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 167s 185ms/step - loss: 1.0375 - accuracy: 0.6662 - val_loss: 1.1432 - val_accuracy: 0.6353
# Epoch 44/50
# 901/901 [==============================] - ETA: 0s - loss: 1.0363 - accuracy: 0.6676
# Epoch 44: val_accuracy did not improve from 0.63530
# 901/901 [==============================] - 184s 204ms/step - loss: 1.0363 - accuracy: 0.6676 - val_loss: 1.1560 - val_accuracy: 0.6306
# Epoch 45/50
# 901/901 [==============================] - ETA: 0s - loss: 1.0359 - accuracy: 0.6662
# Epoch 45: val_accuracy did not improve from 0.63530
# 901/901 [==============================] - 196s 218ms/step - loss: 1.0359 - accuracy: 0.6662 - val_loss: 1.1627 - val_accuracy: 0.6264
# Epoch 46/50
# 901/901 [==============================] - ETA: 0s - loss: 1.0295 - accuracy: 0.6718
# Epoch 46: val_accuracy did not improve from 0.63530
# 901/901 [==============================] - 188s 209ms/step - loss: 1.0295 - accuracy: 0.6718 - val_loss: 1.1810 - val_accuracy: 0.6149
# Epoch 47/50
# 901/901 [==============================] - ETA: 0s - loss: 1.0200 - accuracy: 0.6733
# Epoch 47: val_accuracy did not improve from 0.63530
# 901/901 [==============================] - 187s 208ms/step - loss: 1.0200 - accuracy: 0.6733 - val_loss: 1.2489 - val_accuracy: 0.6057
# Epoch 48/50
# 901/901 [==============================] - ETA: 0s - loss: 1.0306 - accuracy: 0.6697
# Epoch 48: val_accuracy did not improve from 0.63530
# 901/901 [==============================] - 196s 218ms/step - loss: 1.0306 - accuracy: 0.6697 - val_loss: 1.1517 - val_accuracy: 0.6315
# Epoch 49/50
# 901/901 [==============================] - ETA: 0s - loss: 1.0199 - accuracy: 0.6746
# Epoch 49: val_accuracy improved from 0.63530 to 0.63982, saving model to checkpoint\savedModel.h5
# 901/901 [==============================] - 197s 218ms/step - loss: 1.0199 - accuracy: 0.6746 - val_loss: 1.1286 - val_accuracy: 0.6398
# Epoch 50/50
# 901/901 [==============================] - ETA: 0s - loss: 1.0098 - accuracy: 0.6779
# Epoch 50: val_accuracy did not improve from 0.63982
# 901/901 [==============================] - 196s 218ms/step - loss: 1.0098 - accuracy: 0.6779 - val_loss: 1.1304 - val_accuracy: 0.6306

# %%
modelJson = emotionModel.to_json()
with open('emotionModel.json', 'w') as jsonFile:
    jsonFile.write(modelJson)
